# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/premn/OneDrive/Desktop/Trim 4/AI ML/Assignment/train-data.csv')
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC     71 bhp    5.0        NaN   4.00
# 6016  2498 CC    112 bhp    8.0        NaN   2.90
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50
#
# [6019 rows x 14 columns]

# %%
df.shape
# Out:
# (6019, 14)

# %%
#drop unwanted data columns
df.drop(["Unnamed: 0","New_Price"],axis=1,inplace=True)

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [6019 rows x 12 columns]

# %%
#location
df['Location'].value_counts()
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %%
#fuel type
df['Fuel_Type'].value_counts()
# Out:
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
i =df[(df['Fuel_Type']=='LPG') | (df['Fuel_Type']=='Electric')].index
df.drop(i,axis=0,inplace=True)

# %%
#transmission
df['Transmission'].value_counts()
# Out:
# Manual       4289
# Automatic    1718
# Name: Transmission, dtype: int64

# %%
#owner type
df['Owner_Type'].value_counts()
# Out:
# First             4919
# Second             966
# Third              113
# Fourth & Above       9
# Name: Owner_Type, dtype: int64

# %%
i = df[df['Owner_Type']=='Fourth & Above'].index
df.drop(i,axis=0,inplace=True)

# %%
#seats
df['Seats'].value_counts()
# Out:
# 5.0     4998
# 7.0      672
# 8.0      132
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64

# %%
#replace 10, 9, 0 as 6
df['Seats']=np.where(df['Seats']>8,6,df['Seats'])
df.drop(df[df['Seats']==0].index,axis=0,inplace=True)
df['Seats'].value_counts()
# Out:
# 5.0    4998
# 7.0     672
# 8.0     132
# 4.0      99
# 6.0      39
# 2.0      16
# Name: Seats, dtype: int64

# %%
#car name
df['Name'].value_counts()
# Out:
# Mahindra XUV500 W8 2WD                 49
# Maruti Swift VDI                       45
# Honda City 1.5 S MT                    34
# Maruti Swift Dzire VDI                 34
# Maruti Swift VDI BSIV                  31
#                                        ..
# Mahindra Scorpio S10 AT 4WD             1
# Hyundai i20 1.2 Era                     1
# Toyota Camry W4 (AT)                    1
# BMW 5 Series 2013-2017 520d M Sport     1
# Mahindra Xylo D4 BSIV                   1
# Name: Name, Length: 1862, dtype: int64

# %%
#feature splitted as name and model
df['Model']=df['Name'].map(lambda x: str(x).strip().split(" ")[1])
df['Name']=df['Name'].map(lambda x: str(x).strip().split(" ")[0])
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type     Mileage   Engine      Power  Seats  Price   Model
# 0         First  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75   Wagon
# 1         First  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50   Creta
# 2         First   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50    Jazz
# 3         First  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00  Ertiga
# 4        Second   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74      A4
# ...         ...         ...      ...        ...    ...    ...     ...
# 6014      First   28.4 kmpl  1248 CC     74 bhp    5.0   4.75   Swift
# 6015      First   24.4 kmpl  1120 CC     71 bhp    5.0   4.00   Xcent
# 6016     Second   14.0 kmpl  2498 CC    112 bhp    8.0   2.90    Xylo
# 6017      First   18.9 kmpl   998 CC   67.1 bhp    5.0   2.65   Wagon
# 6018      First  25.44 kmpl   936 CC   57.6 bhp    5.0   2.50    Beat
#
# [5997 rows x 13 columns]

# %%
#year
df['Year'].value_counts()
# Out:
# 2014    796
# 2015    744
# 2016    740
# 2013    649
# 2017    587
# 2012    575
# 2011    464
# 2010    339
# 2018    298
# 2009    197
# 2008    171
# 2007    122
# 2019    102
# 2006     77
# 2005     56
# 2004     31
# 2003     17
# 2002     15
# 2001      7
# 2000      4
# 1998      4
# 1999      2
# Name: Year, dtype: int64

# %%
df['Year']=df['Year'].astype(str)
df['Year']=np.where(df['Year'].astype(int)<2003,"less than 2003",df['Year'])
df['Year'].value_counts()
# Out:
# 2014              796
# 2015              744
# 2016              740
# 2013              649
# 2017              587
# 2012              575
# 2011              464
# 2010              339
# 2018              298
# 2009              197
# 2008              171
# 2007              122
# 2019              102
# 2006               77
# 2005               56
# less than 2003     32
# 2004               31
# 2003               17
# Name: Year, dtype: int64

# %%
#mileage
df['Mileage']=df['Mileage'].map(lambda x: str(x).strip().split(" ")[0])
df['Mileage']=df['Mileage'].astype(float)
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type  Mileage   Engine      Power  Seats  Price   Model
# 0         First    26.60   998 CC  58.16 bhp    5.0   1.75   Wagon
# 1         First    19.67  1582 CC  126.2 bhp    5.0  12.50   Creta
# 2         First    18.20  1199 CC   88.7 bhp    5.0   4.50    Jazz
# 3         First    20.77  1248 CC  88.76 bhp    7.0   6.00  Ertiga
# 4        Second    15.20  1968 CC  140.8 bhp    5.0  17.74      A4
# ...         ...      ...      ...        ...    ...    ...     ...
# 6014      First    28.40  1248 CC     74 bhp    5.0   4.75   Swift
# 6015      First    24.40  1120 CC     71 bhp    5.0   4.00   Xcent
# 6016     Second    14.00  2498 CC    112 bhp    8.0   2.90    Xylo
# 6017      First    18.90   998 CC   67.1 bhp    5.0   2.65   Wagon
# 6018      First    25.44   936 CC   57.6 bhp    5.0   2.50    Beat
#
# [5997 rows x 13 columns]

# %%
#engine
def fun(x):
    if x == None:
        return x
    elif len(str(x).split(" "))==2:
        return str(x).split(" ")[0]

# %%
df['Engine']=df['Engine'].apply(fun)

# %%
df['Engine']=df['Engine'].astype(float)

# %%
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type  Mileage  Engine      Power  Seats  Price   Model
# 0         First    26.60   998.0  58.16 bhp    5.0   1.75   Wagon
# 1         First    19.67  1582.0  126.2 bhp    5.0  12.50   Creta
# 2         First    18.20  1199.0   88.7 bhp    5.0   4.50    Jazz
# 3         First    20.77  1248.0  88.76 bhp    7.0   6.00  Ertiga
# 4        Second    15.20  1968.0  140.8 bhp    5.0  17.74      A4
# ...         ...      ...     ...        ...    ...    ...     ...
# 6014      First    28.40  1248.0     74 bhp    5.0   4.75   Swift
# 6015      First    24.40  1120.0     71 bhp    5.0   4.00   Xcent
# 6016     Second    14.00  2498.0    112 bhp    8.0   2.90    Xylo
# 6017      First    18.90   998.0   67.1 bhp    5.0   2.65   Wagon
# 6018      First    25.44   936.0   57.6 bhp    5.0   2.50    Beat
#
# [5997 rows x 13 columns]

# %%
lst = df['Model'].unique()
for i in lst:
    mean_model = df[df["Model"]==i]['Engine'].mean()
    df.update(df[df['Model']==i]['Engine'].fillna(mean_model))

# %%
#power
df['Power']=df['Power'].apply(fun)

# %%
lst = df['Model'].unique()
for i in lst:
    mean_model = df[df["Model"]==i]['Seats'].mode(0)[0]
    df.update(df[df['Model']==i]['Seats'].fillna(mean_model))

# %%
df['Power'] = pd.to_numeric(df['Power'],errors='coerce')

# %%
a = df['Model'].unique()
for i in a:
    r = df[df["Model"]==i]['Power'].astype(float).mean()
    df.update(df[df['Model']==i]['Power'].fillna(r))

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type  Mileage  Engine   Power  Seats  Price   Model
# 0         First    26.60   998.0   58.16    5.0   1.75   Wagon
# 1         First    19.67  1582.0  126.20    5.0  12.50   Creta
# 2         First    18.20  1199.0   88.70    5.0   4.50    Jazz
# 3         First    20.77  1248.0   88.76    7.0   6.00  Ertiga
# 4        Second    15.20  1968.0  140.80    5.0  17.74      A4
# ...         ...      ...     ...     ...    ...    ...     ...
# 6014      First    28.40  1248.0   74.00    5.0   4.75   Swift
# 6015      First    24.40  1120.0   71.00    5.0   4.00   Xcent
# 6016     Second    14.00  2498.0  112.00    8.0   2.90    Xylo
# 6017      First    18.90   998.0   67.10    5.0   2.65   Wagon
# 6018      First    25.44   936.0   57.60    5.0   2.50    Beat
#
# [5983 rows x 13 columns]

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                  object
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# Model                 object
# dtype: object

# %%
#################### END of EDA

# %%
#price vs year
plt.figure(figsize=(15,8))
sns.boxplot(data=df,x="Year",y="Price")
plt.xlabel("Year",size=20,c="g")
plt.ylabel("Price",size=20,c="g")
plt.title("Year vs Price",size=25,c="r")
plt.show()

# %%
#seat frequency
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="Seats")
plt.xlabel("Seats",size=18,c="g")
plt.ylabel("Frequency",size=18,c="g")
plt.show()

# %%
df.describe()
# Out:
#        Kilometers_Driven      Mileage       Engine        Power        Seats  \
# count       5.983000e+03  5983.000000  5983.000000  5983.000000  5983.000000
# mean        5.862153e+04    18.158985  1621.251756   112.814459     5.274277
# std         9.142191e+04     4.551512   599.586823    53.781711     0.784644
# min         1.710000e+02     0.000000   624.000000    34.200000     2.000000
# 25%         3.396550e+04    15.260000  1198.000000    75.000000     5.000000
# 50%         5.300000e+04    18.160000  1493.000000    93.700000     5.000000
# 75%         7.300000e+04    21.100000  1984.000000   138.100000     5.000000
# max         6.500000e+06    33.540000  5998.000000   560.000000     8.000000
#
#              Price
# count  5983.000000
# mean      9.501600
# std      11.194254
# min       0.440000
# 25%       3.500000
# 50%       5.650000
# 75%       9.990000
# max     160.000000

# %%
#removing outliers
#km>300000
df.drop(df[df['Kilometers_Driven']>300000].index,inplace=True,axis=0)

# %%
#power>480
df.drop(df[df['Power']>480].index,inplace=True,axis=0)

# %%
#heatmap
plt.figure(figsize=(10,7))
sns.heatmap(df[["Price","Kilometers_Driven","Power","Mileage","Engine","Seats"]].corr(), annot=True,linewidths=.5,fmt='.1f')
plt.title("Correlation Graph",c="r",size=25)
plt.show()

# %%
#above states that engine and power high correlated thus eliminate engine and drop less correlated features
df.drop(['Mileage','Seats','Engine','Transmission'],axis=1,inplace=True)

# %%
df['Car'] = df['Name'].astype(str) + " " + df['Model']
df.drop(['Name','Model'],axis=1,inplace=True)
df = df[['Car','Location','Year','Kilometers_Driven','Owner_Type','Fuel_Type','Power','Price']]
df
# Out:
#                  Car    Location  Year  Kilometers_Driven Owner_Type  \
# 0       Maruti Wagon      Mumbai  2010              72000      First
# 1      Hyundai Creta        Pune  2015              41000      First
# 2         Honda Jazz     Chennai  2011              46000      First
# 3      Maruti Ertiga     Chennai  2012              87000      First
# 4            Audi A4  Coimbatore  2013              40670     Second
# ...              ...         ...   ...                ...        ...
# 6014    Maruti Swift       Delhi  2014              27365      First
# 6015   Hyundai Xcent      Jaipur  2015             100000      First
# 6016   Mahindra Xylo      Jaipur  2012              55000     Second
# 6017    Maruti Wagon     Kolkata  2013              46000      First
# 6018  Chevrolet Beat   Hyderabad  2011              47000      First
#
#      Fuel_Type   Power  Price
# 0          CNG   58.16   1.75
# 1       Diesel  126.20  12.50
# 2       Petrol   88.70   4.50
# 3       Diesel   88.76   6.00
# 4       Diesel  140.80  17.74
# ...        ...     ...    ...
# 6014    Diesel   74.00   4.75
# 6015    Diesel   71.00   4.00
# 6016    Diesel  112.00   2.90
# 6017    Petrol   67.10   2.65
# 6018    Diesel   57.60   2.50
#
# [5970 rows x 8 columns]

# %%
#car list to dic
lst = df['Car'].unique()
no_models= []
for i in lst:
    df1=df[df['Car']==i]
    no_models.append(len(df1))

# %%
dic = dict(zip(list(lst),no_models))

# %%
sort_orders = sorted(dic.items(), key=lambda x: x[1])
for i in sort_orders:
    print(i[0], i[1])
# Out:
# Mini Countryman 1
# Mini Clubman 1
# Porsche Boxster 1
# Mahindra XUV300 1
# Ambassador Classic 1
# Volkswagen Beetle 1
# Volkswagen Tiguan 1
# Nissan Evalia 1
# Mitsubishi Montero 1
# Tata Venture 1
# Isuzu MUX 1
# Toyota Platinum 1
# Mercedes-Benz CLS-Class 1
# Ford Classic 1
# Datsun Redi 1
# Ford Mustang 1
# Ford Fusion 1
# Mercedes-Benz SL-Class 1
# Maruti Versa 1
# Honda WR-V 1
# Mercedes-Benz SLC 2
# Audi RS5 2
# Renault Lodgy 2
# Audi A8 2
# Nissan Teana 2
# Volvo S80 2
# Mitsubishi Cedia 2
# Mercedes-Benz GLS 2
# Mahindra Renault 2
# Mitsubishi Outlander 2
# Chevrolet Captiva 2
# Fiat Punto 2
# Mahindra Logan 2
# Chevrolet Tavera 2
# Volvo XC90 2
# ISUZU D-MAX 2
# Mitsubishi Lancer 2
# BMW Z4 2
# Nissan X-Trail 3
# Mercedes-Benz C-Class 3
# BMW 1 3
# Mahindra NuvoSport 3
# Jaguar XE 3
# Tata Xenon 3
# Honda BR-V 3
# Renault Captur 3
# Maruti S-Cross 3
# Audi TT 3
# Mercedes-Benz SLK-Class 3
# Renault Koleos 3
# Toyota Qualis 3
# Audi A7 3
# Ford Freestyle 3
# Maruti Grand 3
# Tata Nexon 3
# Force One 3
# Honda WRV 4
# Volvo V40 4
# Mahindra Verito 4
# Hyundai Tucson 4
# Audi A3 4
# Tata Hexa 4
# Fiat Avventura 4
# Ford Aspire 4
# Tata Bolt 4
# Volkswagen CrossPolo 4
# Renault Fluence 4
# Mercedes-Benz R-Class 4
# Fiat Grande 5
# Tata Sumo 5
# Honda BRV 5
# Mahindra Quanto 5
# Mercedes-Benz GLA:18
# Mercedes-Benz GLC:8
# Mercedes-Benz GLE:12
# Mercedes-Benz GLS:2
# Mercedes-Benz M-Class:23
# Mercedes-Benz New:94
# Mercedes-Benz R-Class:4
# Mercedes-Benz S:10
# Mercedes-Benz S-Class:5
# Mercedes-Benz SL-Class:1
# Mercedes-Benz SLC:2
# Mercedes-Benz SLK-Class:3
# Mini Clubman:1
# Mini Cooper:24
# Mini Countryman:1
# Mitsubishi Cedia:2
# Mitsubishi Lancer:2
# Mitsubishi Montero:1
# Mitsubishi Outlander:2
# Mitsubishi Pajero:20
# Nissan Evalia:1
# Nissan Micra:33
# Nissan Sunny:26
# Nissan Teana:2
# Nissan Terrano:26
# Nissan X-Trail:3
# Porsche Boxster:1
# Porsche Cayenne:5
# Porsche Panamera:8
# Renault Captur:3
# Renault Duster:83
# Renault Fluence:4
# Renault Koleos:3
# Renault KWID:40
# Renault Lodgy:2
# Renault Pulse:5
# Renault Scala:5
# Skoda Fabia:11
# Skoda Laura:29
# Skoda Octavia:30
# Skoda Rapid:47
# Skoda Superb:49
# Skoda Yeti:6
# Tata Bolt:4
# Tata Hexa:4
# Tata Indica:40
# Tata Indigo:31
# Tata Manza:16
# Tata Nano:25
# Tata New:8
# Tata Nexon:3
# Tata Safari:9
# Tata Sumo:5
# Tata Tiago:11
# Tata Tigor:5
# Tata Venture:1
# Tata Xenon:3
# Tata Zest:21
# Toyota Camry:11
# Toyota Corolla:68
# Toyota Etios:61
# Toyota Fortuner:101
# Toyota Innova:162
# Toyota Platinum:1
# Toyota Qualis:3
# Volkswagen Ameo:19
# Volkswagen Beetle:1
# Volkswagen CrossPolo:4
# Volkswagen Jetta:23
# Volkswagen Passat:8
# Volkswagen Polo:151
# Volkswagen Tiguan:1
# Volkswagen Vento:106
# Volvo S60:7
# Volvo S80:2
# Volvo V40:4
# Volvo XC60:6
# Volvo XC90:2

# %%
#drop less frequency than 10
l = df['Car'].value_counts()[df['Car'].value_counts()<10].index
df[df['Car'].isin(l)]
# Out:
#                         Car    Location  Year  Kilometers_Driven Owner_Type  \
# 21                 Maruti S   Bangalore  2015              55392     Second
# 28                Honda WRV       Kochi  2018              37430      First
# 49            Mahindra Thar      Jaipur  2012              75800     Second
# 58           Nissan X-Trail   Hyderabad  2010             121812      First
# 67    Mercedes-Benz C-Class  Coimbatore  2019              15369      First
# ...                     ...         ...   ...                ...        ...
# 5979            ISUZU D-MAX      Jaipur  2017              25000      First
# 5982              Tata Hexa      Jaipur  2016              39000      First
# 5990               Tata New        Pune  2008              86000      Third
# 5999              Tata Bolt     Chennai  2016              10000      First
# 6008       Porsche Panamera   Hyderabad  2013              40000     Second
#
#      Fuel_Type   Power  Price
# 21      Diesel   88.50   8.25
# 28      Petrol   88.70   9.90
# 49      Diesel  105.00   5.50
# 58      Diesel  147.60   7.75
# 67      Diesel  194.00  35.67
# ...        ...     ...    ...
# 5979    Diesel  134.00   8.00
# 5982    Diesel  153.86  13.50
# 5990    Diesel  138.00   0.60
# 5999    Petrol   88.70   4.00
# 6008    Diesel  300.00  45.00
#
# [357 rows x 8 columns]

# %%
df.drop(df[df['Car'].isin(l)].index,inplace=True,axis=0)

# %%
df_new = df.copy()

# %%
df.shape
# Out:
# (5970, 8)

# %%
df.dtypes
# Out:
# Car                   object
# Location              object
# Year                  object
# Kilometers_Driven      int64
# Owner_Type            object
# Fuel_Type             object
# Power                float64
# Price                float64
# dtype: object

# %%
df[['Car','Location','Year','Owner_Type','Fuel_Type']].nunique()
# Out:
# Car           204
# Location       11
# Year           18
# Owner_Type      3
# Fuel_Type       3
# dtype: int64

# %%
df1=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
#encoding categorical variable
lst = ['Car','Location','Fuel_Type']

# %%
for i in lst:
    le = LabelEncoder()
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       Car  Location  Year  Kilometers_Driven Owner_Type  Fuel_Type   Power  \
# 0     117         9  2010              72000      First          0   58.16
# 1      62        10  2015              41000      First          1  126.20
# 2      57         2  2011              46000      First          2   88.70
# 3     105         2  2012              87000      First          1   88.76
# 4       2         3  2013              40670     Second          1  140.80
# ...   ...       ...   ...                ...        ...        ...     ...
# 6014  114         4  2014              27365      First          1   74.00
# 6015   73         6  2015             100000      First          1   71.00
# 6016   96         6  2012              55000     Second          1  112.00
# 6017  117         8  2013              46000      First          2   67.10
# 6018   22         5  2011              47000      First          1   57.60
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [5970 rows x 8 columns]

# %%
#ordinal encoding for year and owner type
df['Owner_Type'].value_counts()
# Out:
# First     4900
# Second     959
# Third      111
# Name: Owner_Type, dtype: int64

# %%
dic = {'First':2,'Second':1,'Third':0}

# %%
df['Year'].value_counts()
# Out:
# 2014              796
# 2015              741
# 2016              740
# 2013              646
# 2017              585
# 2012              575
# 2011              460
# 2010              335
# 2018              298
# 2009              195
# 2008              167
# 2007              122
# 2019              102
# 2006               76
# 2005               55
# 2004               31
# less than 2003     29
# 2003               17
# Name: Year, dtype: int64

# %%
dic1 = {'2019':17,"2018":16,"2017":15,"2016":14,"2015":13,"2014":12,"2013":11,"2012":10,"2011":9,"2010":8,"2009":7,"2008":6,"2007":5,"2006":4,"2005":3,"2004":2,"2003":1,"less than 2003":0 }

# %%
df['Owner_Type']=df['Owner_Type'].map(dic)
df['Year']=df['Year'].map(dic1)

# %%
df
# Out:
#       Car  Location  Year  Kilometers_Driven  Owner_Type  Fuel_Type   Power  \
# 0     117         9     8              72000           2          0   58.16
# 1      62        10    13              41000           2          1  126.20
# 2      57         2     9              46000           2          2   88.70
# 3     105         2    10              87000           2          1   88.76
# 4       2         3    11              40670           1          1  140.80
# ...   ...       ...   ...                ...         ...        ...     ...
# 6014  114         4    12              27365           2          1   74.00
# 6015   73         6    13             100000           2          1   71.00
# 6016   96         6    10              55000           1          1  112.00
# 6017  117         8    11              46000           2          2   67.10
# 6018   22         5     9              47000           2          1   57.60
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [5970 rows x 8 columns]

# %%
###########################################################

# %%
#Model training
X = df.drop("Price",axis=1)   #X --- > Independent variables
Y= df['Price']                #Y --- > Dependent variables

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
import statsmodels.api as sm
X_train = sm.add_constant(X_train)  
model = sm.OLS(Y_train, X_train).fit(cov_type='HAC', cov_kwds={'maxlags': 1})

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.681
# Method:                 Least Squares   F-statistic:                     362.0
# Date:                Fri, 20 Oct 2023   Prob (F-statistic):               0.00
# Time:                        14:35:30   Log-Likelihood:                -15530.
# No. Observations:                4776   AIC:                         3.108e+04
# Df Residuals:                    4768   BIC:                         3.113e+04
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -11.0463      1.017    -10.862      0.000     -13.040      -9.053
# Car                4.671e-05      0.002      0.027      0.979      -0.003       0.003
# Location             -0.2130      0.029     -7.309      0.000      -0.270      -0.156
# Year                  0.7779      0.038     20.511      0.000       0.704       0.852
# Kilometers_Driven -3.146e-05   3.32e-06     -9.474      0.000    -3.8e-05    -2.5e-05
# Owner_Type            0.1363      0.211      0.645      0.519      -0.278       0.551
# Fuel_Type            -2.0573      0.203    -10.132      0.000      -2.455      -1.659
# Power                 0.1543      0.004     35.625      0.000       0.146       0.163
# ==============================================================================
# Omnibus:                     3870.174   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           371496.790
# Skew:                           3.259   Prob(JB):                         0.00
# Kurtosis:                      45.712   Cond. No.                     6.24e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 6.24e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_test = sm.add_constant(X_test)
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, accuracy_score
mae_train = mean_absolute_error(Y_train, y_train_pred)
mape_train = mean_absolute_percentage_error(Y_train, y_train_pred)
rmse_train = np.sqrt(mean_squared_error(Y_train, y_train_pred))

mae_test = mean_absolute_error(Y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(Y_test, y_test_pred)
rmse_test = np.sqrt(mean_squared_error(Y_test, y_test_pred))

# %%
print("Training Set Metrics:")
print(f"MAE (Training): {mae_train}")
print(f"MAPE (Training): {mape_train}")
print(f"RMSE (Training): {rmse_train}")


print("\nTesting Set Metrics:")
print(f"MAE (Testing): {mae_test}")
print(f"MAPE (Testing): {mape_test}")
print(f"RMSE (Testing): {rmse_test}")
# Out:
# Training Set Metrics:
# MAE (Training): 3.7919093751080717
# MAPE (Training): 0.7695381850956967
# RMSE (Training): 6.251219422468442
#
# Testing Set Metrics:
# MAE (Testing): 3.6609704003699983
# MAPE (Testing): 0.7717420516978809
# RMSE (Testing): 5.504422644434843

# %%
#linearityCar	Location	Year	Kilometers_Driven	Owner_Type	Fuel_Type	Power	Price
import matplotlib.pyplot as plt

# Create a scatter plot
plt.scatter(df['Kilometers_Driven'], df['Price'])

# Add labels and a title
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.title('Scatter Plot of Independent vs. Dependent Variable')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df['Owner_Type'], df['Price'])

# Add labels and a title
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.title('Scatter Plot of Independent vs. Dependent Variable')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df['Power'], df['Price'])

# Add labels and a title
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.title('Scatter Plot of Independent vs. Dependent Variable')

# Show the plot
plt.show()

# %%
#multicollineariy
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Assuming you have a DataFrame 'df' with multiple independent variables
X = df[["Location","Year","Kilometers_Driven","Owner_Type","Fuel_Type","Power"]]

# Add a constant (intercept) to the features
#X = sm.add_constant(X)


# Create a DataFrame to store the VIF results
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Display the VIF results
print(vif_data)
# Out:
#             Variable        VIF
# 0           Location   4.475370
# 1               Year  14.545319
# 2  Kilometers_Driven   3.305618
# 3         Owner_Type  18.126481
# 4          Fuel_Type   6.734472
# 5              Power   5.143504

# %%
import matplotlib.pyplot as plt

# Calculate the residuals for the training data
residuals = Y_train - y_train_pred

# Create a scatter plot of residuals against predicted values
plt.scatter(y_train_pred, residuals, c='b')
plt.axhline(y=0, color='r', linestyle='--')  # Add a horizontal line at y=0 for reference
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot for Training Data")
plt.show()
